# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# Seaborn is a Python data visualization library based on matplotlib
import seaborn as sns

# %%
data = pd.read_csv("../data/suicidedataextrafestures.csv")
data.head()
# Out:
#      country  year     sex          age  suicides_no  population  \
# 0  Argentina  1985    male    75+ years          202      363000
# 1  Argentina  1985    male  55-74 years          485     1997000
# 2  Argentina  1985    male  35-54 years          414     3346300
# 3  Argentina  1985  female  55-74 years          210     2304000
# 4  Argentina  1985    male  25-34 years          177     2234200
#
#    suicidesper100k   country-year  yearlyHDI      GDPpyear  ...  \
# 0            55.65  Argentina1985      0.694  8.841667e+10  ...
# 1            24.29  Argentina1985      0.694  8.841667e+10  ...
# 2            12.37  Argentina1985      0.694  8.841667e+10  ...
# 3             9.11  Argentina1985      0.694  8.841667e+10  ...
# 4             7.92  Argentina1985      0.694  8.841667e+10  ...
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                0.0
# 1                                                0.0
# ...

# %%
suicides_by_country_and_year = data.groupby(['country', 'year'])\
    .aggregate({'suicides_no': 'sum'})

# %%
suicides_by_country = data.groupby('country')\
    .aggregate({'suicides_no': 'sum'})

# %%
suicides_by_country_and_year.head()
# Out:
#                 suicides_no
# country   year
# Argentina 1985         1988
#           1986         2284
#           1987         2286
#           1988         2354
#           1989         2247

# %%
suicides_by_country_and_year.loc['Argentina']
# Out:
#       suicides_no
# year
# 1985         1988
# 1986         2284
# 1987         2286
# 1988         2354
# 1989         2247
# 1990         2140
# 1991         1951
# 1992         2184
# 1993         2230
# 1994         2241
# 1995         2204
# 1996         2229
# 1997         2184
# 1998         2347
# 1999         2423
# 2000         2774
# 2001         3132
# 2002         3162
# 2003         3289
# 2004         3121
# 2005         3058
# 2006         3108
# 2007         2946
# 2008         3059
# 2009         2884
# 2010         2943
# 2011         2912
# 2012         3248
# 2013         2987
# 2014         3231
# 2015         3073

# %%
sns.relplot(x="year", y="suicides_no", col="country", data=data,
            kind="line")
