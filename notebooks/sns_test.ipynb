# %%
import seaborn as sns
sns.set()
tips = sns.load_dataset("tips")

# %%
graph = sns.relplot(
    x="total_bill",
    y="tip",
    col="time",
    hue="smoker",
    style="smoker",
    size="size",
    data=tips);
